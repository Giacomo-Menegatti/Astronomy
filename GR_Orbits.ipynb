# %% [markdown]
# # GR orbit versus normal orbit

# %%
from scipy import integrate, interpolate
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure('Orbit plot')
ax = plt.subplot(projection = 'polar')

phi = np.linspace(0,5*np.pi, 1000)
ax.plot(phi, 1+0.5*np.cos(5*phi))
